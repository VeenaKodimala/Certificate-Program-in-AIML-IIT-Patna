# %%
from dotenv import load_dotenv
import requests
#This is imported to access the env cariables.
import os

load_dotenv()

api_key=os.getenv('GroqAPIKey')

# %%
# %pip install Groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#here, Groq is a python SDK/API provider to call the available LLM models with it. Eg: check in Groq's website. Now Groq can call only the models that are available with it. Same goes for Anthropic, Cohere, TogetherAI. but with OpenAI API provider, we call multiple agents/LLM's by providing the base url of the API. Eg: I can use OpenAPI SDK and call, groq's. So, using Groq we can communicate with different models, that are built by some others.

from groq import Groq
