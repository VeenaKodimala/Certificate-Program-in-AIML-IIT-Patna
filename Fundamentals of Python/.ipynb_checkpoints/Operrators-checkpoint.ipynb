# %% [markdown]
# # Operators in Python

# %% [markdown]
# ### Arithmatic Operators
#
# ![image.png](attachment:38e04cf8-3cd7-45be-a9d8-420508027ed9.png)    ![image.png](attachment:02cd7773-2578-4eda-bac4-24d692003743.png)
#
# In the above image, "/" returns the result with decimal and "//" return w/o decimal. "%" will return the reminder. "**" will return power of first number to second.

# %% [markdown]
# ### Conditional operators
#
# ![image.png](attachment:4ba4fd49-3458-48ce-b7ea-22e1777ea533.png)

# %%
a=10
b=9
c=10

print(a == b)
print(a == c)
print(a > c)
print(a < c)
print(a != c)
# Out:
# False
# True
# False
# False
# False

# %% [markdown]
# ### Logical Operators - and, or and not

# %%
#In Python, when you use a variable in an if statement, Python checks its "truthiness."
#n=7: Any non-zero integer is considered True.
#o="9": Any non-empty string is considered True. Even though it is a string containing a number, it is not empty, so it is treated as True. 

#AND
n=7
m=9
o="9"

if(n and o):
    print("Hello there!!!")
else:
    print("Good day mate!!")

#OR
n=0
m=9
o=""

if(n or o):
    print("Hello there!!!")
else:
    print("Good day mate!!")

#NOT
n=0
m=9
o=""

if(not o):
    print("Hello there!!!")
else:
    print("Good day mate!!")
# Out:
# Hello there!!!
# Good day mate!!
# Hello there!!!
