# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
houseParams = {"area_sqft":[1200,1500,900,1800],
                "bedrooms":[3,4,2,4],
                 "age_years":[5,2,10,1], 
                 "price_lakhs":[45,65,30,80]}
houseData = pd.DataFrame(houseParams)
display(houseData)
# Out:
#    area_sqft  bedrooms  age_years  price_lakhs
# 0       1200         3          5           45
# 1       1500         4          2           65
# 2        900         2         10           30
# 3       1800         4          1           80

# %%
x = houseData[["area_sqft","bedrooms","age_years"]]
y = houseData[["price_lakhs"]]

display(x)
display(y)
# Out:
#    area_sqft  bedrooms  age_years
# 0       1200         3          5
# 1       1500         4          2
# 2        900         2         10
# 3       1800         4          1
#    price_lakhs
# 0           45
# 1           65
# 2           30
# 3           80

# %%
xTrain,xTest,yTrain,yTest = train_test_split(x,y,random_state=0,test_size=0.25)

# %%
xTrain
# Out:
#    area_sqft  bedrooms  age_years
# 3       1800         4          1
# 1       1500         4          2
# 0       1200         3          5

# %%
scalar = StandardScaler()
numericCols=['area_sqft','bedrooms','age_years']
xTrain[numericCols]=scalar.fit_transform(xTrain[numericCols])
xTest[numericCols]=scalar.transform(xTest[numericCols])

# %%
housePredictionModel = LinearRegression()
housePredictionModel.fit(xTrain,yTrain)

print(f"House Prediction Model's coefficients::: \n{housePredictionModel.coef_}")
print(f"House Prediction Model's intercept::: \n{housePredictionModel.intercept_}")
# Out:
# House Prediction Model's coefficients:::
# [[10.00208312 -0.23570226 -4.67410122]]
# House Prediction Model's intercept:::
# [63.33333333]

# %%
yTestPred = housePredictionModel.predict(xTest)

testMAE = mean_absolute_error(yTest,yTestPred)

print(f"MAE on test data: {testMAE:.2f}")
# Out:
# MAE on test data: 10.50
