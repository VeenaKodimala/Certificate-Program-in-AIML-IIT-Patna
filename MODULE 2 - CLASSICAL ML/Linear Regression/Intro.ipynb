# %% [markdown]
# ### What is Equation of line:

# %% [markdown]
# ![image.png](attachment:image.png)
# - C=Intercept(**Prediction when ALL features are zero, i.e, y=c**), The distance from origin to the point where my line meets the y-axis. In machine learning, it is called as **Bias**
# - m = slope of line (the angle between the line and the x-axis line), In ML it is called as **Coefficient**

# %% [markdown]
# ### What my Linear Regression can predict
# ![image.png](attachment:image.png)
# Here what will be the marks if my study hours is 11? x=11.
# - If we were able to plot or get the best-fit line, meeting the input data, then then we can find the y(output) for any given input.
# - The task of finding this best-fit line will be done by out ML modrl.

# %% [markdown]
# ### How will the model predicts best-fit line?
# ![image.png](attachment:image.png)
# - Slope is the most important parameter in linear Reg(LR). Because it is the rate of change. From the above line, for every one hour, the acore goes up by slope value(6.2)
# - ![image-2.png](attachment:image-2.png)
# - From the above image we know that L2 is the best-fit line, because it is touching all the points(input). But how will machine decide this?
# - If I consider any line as perfect file, then the distanc between the actual point and the perfect-line should be as mim as possible or it should be 0. This distance is called as **"Residual"**(refer below img). Sum of all the residuals will give us the ***Total Residual***.
# - ML algo will first draw a random line, tweak the "m" and"c" internally, draw infinite no.of lines recurssively, by changing the slope, until it gets the least Total Residual. Once it finds the least residual, it fixes the "Best Fit Line).
# ![image-3.png](attachment:image-3.png)
# - So, more technically, the model will find the ***Sum of Squared Errors*** - How far the predicted values are from the actual values, i.e , SSE=∑(actualval ​− predictedval​)^2. Why squaring, to tell the model that the outliers also should be considered. Like if i say to the model that my residual is around 12, it is quite small, but if it is like 102, then the machine will take tha tinto consideration.
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Since we are dealing with lines, that is why it is called as "Linear Regression"

# %% [markdown]
# #### Now, the images which we were reffeiring till now, only shows lines, because they are all of one feature, what if we have multiple features like in Car_dekno dataset? Then we will have a plane touching all points, instead of a line.
# ![image.png](attachment:image.png)
# - This is how we calculate "y" when we have multiple features
# ![image-2.png](attachment:image-2.png)
# - From our car_dekho dataset:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# t
