# %%
import pandas as pd
import numpy as np

data = {
    'car_name':  ['Maruti Swift', 'Honda City', 'Ferrari 488', 'Hyundai i20',
                  'Toyota Innova', 'Maruti Baleno', 'BMW 5 Series', 'Tata Nexon',
                  'Ferrari Roma', 'Honda Amaze', 'BMW 3 Series', 'Hyundai Creta'],
    'car_age':   [5, 3, 2, 7, 4, 6, 3, 5, 1, 4, 6, 2],
    'km_driven': [45000, 28000, 5000, 72000, 38000, 55000, 22000, 48000,
                  3000, 35000, 60000, 18000],
    'engine_cc': [1197, 1498, 3902, 1197, 2694, 1197, 1998, 1497,
                  3855, 1199, 1998, 1497],
    'fuel':      ['Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel',
                  'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Diesel'],
    'brand':     ['Maruti', 'Honda', 'Ferrari', 'Hyundai', 'Toyota',
                  'Maruti', 'BMW', 'Tata', 'Ferrari', 'Honda', 'BMW', 'Hyundai'],
    'price':     [5.2, 8.4, 220.0, 3.8, 12.5, 4.9, 38.0, 7.1,
                  210.0, 6.8, 35.0, 11.2]
}

df = pd.DataFrame(data)

# %%
df = df.drop(columns=['car_name'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   car_age    12 non-null     int64
#  1   km_driven  12 non-null     int64
#  2   engine_cc  12 non-null     int64
#  3   fuel       12 non-null     str
#  4   brand      12 non-null     str
#  5   price      12 non-null     float64
# dtypes: float64(1), int64(3), str(2)
# memory usage: 708.0 bytes

# %%
print(f"SHape of df b4 OHE: {df.shape}")
df = pd.get_dummies(df,columns=['fuel','brand'],drop_first=True)
print(f"SHape of df after OHE: {df.shape}")
print(f"Columns of df: {df.columns.to_list()}")
# Out:
# SHape of df b4 OHE: (12, 6)
# SHape of df after OHE: (12, 11)
# Columns of df: ['car_age', 'km_driven', 'engine_cc', 'price', 'fuel_Petrol', 'brand_Ferrari', 'brand_Honda', 'brand_Hyundai', 'brand_Maruti', 'brand_Tata', 'brand_Toyota']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

x = df.drop(columns=['price'])
y = df['price']

print(f"columns of x: {x.columns.to_list()}")


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

numericCols=['car_age','km_driven','engine_cc']

scalar = StandardScaler()
#fit will find mean and std, transform will apply the standardization formula on each data point.
#This can be done seperately as well, like .fit(), .transform()
x_train[numericCols]=scalar.fit_transform(x_train[numericCols])

print(f"data after scaling: \n{x_train}")
print(f"details of x_train after scaling: \n{x_train.describe()}")
# Out:
# columns of x: ['car_age', 'km_driven', 'engine_cc', 'fuel_Petrol', 'brand_Ferrari', 'brand_Honda', 'brand_Hyundai', 'brand_Maruti', 'brand_Tata', 'brand_Toyota']
# data after scaling:
#      car_age  km_driven  engine_cc  fuel_Petrol  brand_Ferrari  brand_Honda  \
# 8  -1.414214  -1.331374   1.670859         True           True        False
# 5   1.237437   1.046805  -0.931373         True          False        False
# 2  -0.883883  -1.239905   1.716873         True           True        False
# 1  -0.353553  -0.188018  -0.636689        False          False         True
# 11 -0.883883  -0.645361  -0.637668        False          False        False
# 4   0.176777   0.269324   0.534218        False          False        False
# 7   0.707107   0.726666  -0.637668        False          False        False
# 3   1.767767   1.824287  -0.931373         True          False        False
# 6  -0.353553  -0.462424  -0.147179         True          False        False
#
#     brand_Hyundai  brand_Maruti  brand_Tata  brand_Toyota
# 8           False         False       False         False
# 5           False          True       False         False
# 2           False         False       False         False
# 1           False         False       False         False
# 11           True         False       False         False
# 4           False         False       False          True
# 7           False         False        True         False
# 3            True         False       False         False
# 6           False         False       False         False
# details of x_train after scaling:
#             car_age     km_driven     engine_cc
# count  9.000000e+00  9.000000e+00  9.000000e+00
# mean   5.551115e-17  9.868649e-17 -1.572816e-16
# std    1.060660e+00  1.060660e+00  1.060660e+00
# min   -1.414214e+00 -1.331374e+00 -9.313735e-01
# 25%   -8.838835e-01 -6.453605e-01 -6.376677e-01
# 50%   -3.535534e-01 -1.880184e-01 -6.366887e-01
# 75%    7.071068e-01  7.266658e-01  5.342181e-01
# max    1.767767e+00  1.824287e+00  1.716873e+00

# %%
x_test[numericCols]=scalar.transform(x_test[numericCols])

print(f"data after scaling: \n{x_test}")
print(f"details of x_train after scaling: \n{x_test.describe()}")
# Out:
# data after scaling:
#      car_age  km_driven  engine_cc  fuel_Petrol  brand_Ferrari  brand_Honda  \
# 10  1.237437   1.275476  -0.147179         True          False        False
# 9   0.176777   0.132121  -0.929415         True          False         True
# 0   0.707107   0.589463  -0.931373         True          False        False
#
#     brand_Hyundai  brand_Maruti  brand_Tata  brand_Toyota
# 10          False         False       False         False
# 9           False         False       False         False
# 0           False          True       False         False
# details of x_train after scaling:
#         car_age  km_driven  engine_cc
# count  3.000000   3.000000   3.000000
# mean   0.707107   0.665687  -0.669323
# std    0.530330   0.575476   0.452191
# min    0.176777   0.132121  -0.931373
# 25%    0.441942   0.360792  -0.930394
# 50%    0.707107   0.589463  -0.929415
# 75%    0.972272   0.932470  -0.538297
# max    1.237437   1.275476  -0.147179
