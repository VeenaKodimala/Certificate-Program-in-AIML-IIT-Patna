# %% [markdown]
# ### Problems in Real world
#
# 1. Security - What if your API key is being stolen? You have added you credit card and generated an API key, it has been stolen by a hacker. Now next day, you get a bill of 500000 for usage of API key. How to secure your API keys, so that it doesn't get stolen?
# 2. Ethics - What if you have posted your personal data in insta, and someone have scraped your personal dat awithout your consent? This is unethical. How to prevent it?
